# %% [markdown]
# # In this tutorial, we will learn a high level data visualization library- seaborn
# - tutorial references:
#  - https://seaborn.pydata.org/generated/seaborn.barplot.html
#  - https://seaborn.pydata.org/index.html
#  - https://www.kaggle.com/learn/data-visualization

# %%
# set up the notebook

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters() # link pandas to matplotlib packages
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %%
# Path of the file to read
fifa_filepath = "../fifa.csv"
# Read the file into a variable fifa_data
fifa_data = pd.read_csv(fifa_filepath,index_col='Date',parse_dates=True)

# %%
fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %%
fifa_data.columns
# Out:
# Index(['ARG', 'BRA', 'ESP', 'FRA', 'GER', 'ITA'], dtype='object')

# %%
# lets plot the line graph
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Line chart showing how FIFA rankings evolved over time 
sns.lineplot(data=fifa_data)

# %%
# set the title of graph
# Set the width and height of the figure
plt.figure(figsize=(16,6))
plt.title("FIFA Ranking timeseries of six countires")
plt.ylabel('Ranking')
# Line chart showing how FIFA rankings evolved over time 
sns.lineplot(data=fifa_data)

# %%
# plot a subset of data
# set the title of graph
# Set the width and height of the figure
plt.figure(figsize=(16,6))
plt.title("FIFA Ranking timeseries of Argentine countires")
plt.ylabel('Ranking')
# Line chart showing how FIFA rankings evolved over time 
sns.lineplot(data=fifa_data[['ARG','BRA']])

# %%
# Bar chart and Heatmaps - lets use seasborn built in dataset for these plot

# %%
import seaborn as sns
sns.set_style(style="whitegrid") # background theme
tips = sns.load_dataset("tips") # built-in dataset

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
ax = sns.barplot(x="day", y="total_bill", data=tips) # barplot

# %%
sns.barplot(x="day", y="total_bill", hue="sex", data=tips) # draw bar fir each sex group

# %%
sns.barplot(x="total_bill", y="day", hue="sex", data=tips) # by deafault it arrange data in horizntal bar

# %%
# cat-plot: categorical plot in seaborn
g = sns.catplot(x="sex", y="total_bill",
                hue="smoker", col="time",
                data=tips, kind="bar",
                height=4, aspect=.7)

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# there are three steps in using seaborn for plotting
plt.figure(figsize= (10,5))
plt.title("Scater plot")
plt.xlabel("Sex")
plt.ylabel('Total Bill')
sns.scatterplot(x='tip',y='total_bill', hue='sex',data=tips)
